# %%
# load magic modules
import numpy as np 
import matplotlib.pyplot as plt

# %%
# load data
t,x,y = np.loadtxt("tracker2.txt", unpack=True)
# plotting magic
plt.plot(t,0.1*x, 'o-', label="x coordinate")
plt.title("Real Data")
plt.legend()
plt.show()
